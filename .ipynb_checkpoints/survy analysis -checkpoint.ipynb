# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('survey_results_public.csv',index_col='ResponseId')
dfsch=pd.read_csv('survey_results_schema.csv',index_col='qname')

# %%
dfsch.loc['NEWOtherComms'].values
# Out:
# array(['QID267',
#        'Are you a member of any other online developer communities?',
#        False, 'MC', 'MAVR'], dtype=object)

# %%
dfsch.drop(['qid','force_resp','type','selector'],axis=1,inplace=True)

# %%
pd.set_option('display.max_columns',48)
pd.set_option('display.max_rows',30)

# %%
len(df.columns)
# Out:
# 47

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83439 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    83439 non-null  object
#  1   Employment                    83323 non-null  object
#  2   Country                       83439 non-null  object
#  3   US_State                      14920 non-null  object
#  4   UK_Country                    4418 non-null   object
#  5   EdLevel                       83126 non-null  object
#  6   Age1stCode                    83243 non-null  object
#  7   LearnCode                     82963 non-null  object
#  8   YearsCode                     81641 non-null  object
#  9   YearsCodePro                  61216 non-null  object
#  10  DevType                       66484 non-null  object
#  11  OrgSize                       60726 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# MainBranch                 0
# Employment               116
# Country                    0
# US_State               68519
# UK_Country             79021
#                        ...
# Accessibility           5836
# MentalHealth            6519
# SurveyLength            1728
# SurveyEase              1491
# ConvertedCompYearly    36595
# Length: 47, dtype: int64

# %%
df.drop(['US_State','UK_Country','Sexuality','Ethnicity','Accessibility','OrgSize','PlatformHaveWorkedWith','LanguageWantToWorkWith','DatabaseWantToWorkWith','PlatformWantToWorkWith','MiscTechWantToWorkWith','WebframeWantToWorkWith','ToolsTechHaveWorkedWith','NEWCollabToolsWantToWorkWith','ToolsTechWantToWorkWith','NEWCollabToolsWantToWorkWith','SOPartFreq','SOComm','Trans','MentalHealth','SurveyLength','SurveyEase','ConvertedCompYearly'],axis=1,inplace=True)

# %%
df['Employment']=df['Employment'].fillna(method='pad')

# %%
df['Country']=df['Country'].fillna(value=df['Country'].value_counts().index[0])

# %%
df['EdLevel']=df['EdLevel'].fillna(method='pad')

# %%
df['Age1stCode']=df['Age1stCode'].fillna(value=df['Age1stCode'].value_counts().index[0])

# %%
df['LearnCode']=df['LearnCode'].fillna(method='pad')

# %%
from math import floor
df['YearsCodePro'].replace({'Less than 1 year':0,'More than 50 years':51},inplace=True)
df['YearsCodePro']=df['YearsCodePro'].astype(float)
df['YearsCodePro']=df['YearsCodePro'].fillna(value=floor(df['YearsCodePro'].mean()))

# %%
df['DevType']=df['DevType'].fillna(method='pad')

# %%
df['Currency']=df['Currency'].fillna(method='pad')

# %%
df['CompTotal']=df['CompTotal'].fillna(value=floor(df['CompTotal'].median()))

# %%
df['CompFreq']=df['CompFreq'].fillna(method='pad')

# %%
df['LanguageHaveWorkedWith']=df['LanguageHaveWorkedWith'].fillna(method='pad')

# %%
df['LanguageHaveWorkedWith']=df['LanguageHaveWorkedWith'].fillna(method='pad')

# %%
df['DatabaseHaveWorkedWith']=df['DatabaseHaveWorkedWith'].fillna(method='pad')

# %%
df['WebframeHaveWorkedWith']=df['WebframeHaveWorkedWith'].fillna(method='pad')

# %%
df['MiscTechHaveWorkedWith']=df['MiscTechHaveWorkedWith'].fillna(method='pad')

# %%
df['NEWCollabToolsHaveWorkedWith']=df['NEWCollabToolsHaveWorkedWith'].fillna(method='pad')

# %%
df['OpSys']=df['OpSys'].fillna(method='pad')

# %%
df['NEWStuck']=df['NEWStuck'].fillna(method='pad')
df['NEWSOSites']=df['NEWSOSites'].fillna(method='pad')
df['SOVisitFreq']=df['SOVisitFreq'].fillna(method='pad')
df['SOAccount']=df['SOAccount'].fillna(method='pad')
df['NEWOtherComms']=df['NEWOtherComms'].fillna(method='pad')

# %%
df['Age'].replace({'25-34 years old':floor((29+34)/2),'18-24 years old':floor((18+24)/2),'35-44 years old':floor((34+44)/2),'Prefer not to say':np.nan,'45-54 years old':floor((45+54)/2),'Under 18 years old':17,'65 years or older':66,'55-64 years old':floor((55+64)/2),'nan':np.nan},inplace=True)
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df['YearsCode'].replace({'Less than 1 year':0,'More than 50 years':51},inplace=True)
df['YearsCode']=df['YearsCode'].astype(float)

# %%
df['YearsCode'].replace({np.nan:floor(df['YearsCode'].mean())},inplace=True)

# %%
df['Gender'].replace({'Prefer not to say':np.nan,'Non-binary, genderqueer, or gender non-conforming':np.nan,'Man;Or, in your own words:':'Man','Woman;Or, in your own words:':'Woman','Woman;Non-binary, genderqueer, or gender non-conforming':'Woman','Man;Non-binary, genderqueer, or gender non-conforming':'Man','Or, in your own words:':np.nan,'Man;Woman':'Man','Man;Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:':'Man','Non-binary, genderqueer, or gender non-conforming;Or, in your own words:':'Man','Man;Woman;Non-binary, genderqueer, or gender non-conforming':'Man','Man;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:':'Man','Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:':'Woman','Man;Woman;Or, in your own words:':'Man'},inplace=True)
df['Gender']=df['Gender'].fillna(value=df['Gender'].value_counts().index[0])

# %%
df.isnull().sum()
# Out:
# MainBranch                      0
# Employment                      0
# Country                         0
# EdLevel                         0
# Age1stCode                      0
# LearnCode                       0
# YearsCode                       0
# YearsCodePro                    0
# DevType                         0
# Currency                        0
# CompTotal                       0
# CompFreq                        0
# LanguageHaveWorkedWith          0
# DatabaseHaveWorkedWith          0
# WebframeHaveWorkedWith          0
# MiscTechHaveWorkedWith          1
# NEWCollabToolsHaveWorkedWith    0
# OpSys                           0
# NEWStuck                        0
# NEWSOSites                      0
# SOVisitFreq                     0
# SOAccount                       0
# NEWOtherComms                   0
# Age                             0
# Gender                          0
# dtype: int64

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df['Country'].value_counts()[:20].plot(kind='bar')
plt.title('num of programers');

# %%
lang=df.copy()
lang['LanguageHaveWorkedWith']=lang['LanguageHaveWorkedWith'].astype(str).apply(lambda x:x.split(';'))
lang=lang.explode('LanguageHaveWorkedWith')
lang['LanguageHaveWorkedWith'].value_counts(normalize=True).plot(kind='bar')
sns.set(rc={'figure.figsize': [25,15]}, font_scale=2)
plt.title('most used languages');

# %%
country_grp = df.groupby(['Country'])
x=country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
Country = df['Country'].value_counts()
python_df = pd.concat([country_respondents, x], axis='columns', sort=False)
python_df.rename(columns={'LanguageHaveWorkedWith': 'python user','Country':'num_people'}, inplace=True)
python_df['PctKnowsPython'] = (python_df['python user']/python_df['num_people']) * 100
python_df.head(10)
# Out:
#                                                     num_people  python user  \
# United States of America                                 15288         8054
# India                                                    10511         5349
# Germany                                                   5625         2729
# United Kingdom of Great Britain and Northern Ir...        4475         2166
# Canada                                                    3012         1607
# France                                                    2708         1433
# Brazil                                                    2254          963
# Poland                                                    1805          821
# Netherlands                                               1772          836
# Italy                                                     1666          741
#
#                                                     PctKnowsPython
# ...

# %%
x=country_grp['DatabaseHaveWorkedWith'].apply(lambda x: x.str.contains('PostgreSQL').sum())
python_df = pd.concat([country_respondents, x], axis='columns', sort=False)
python_df.rename(columns={'DatabaseHaveWorkedWith': 'PostgreSQL user','Country':'num_people'}, inplace=True)
python_df['PctKnowsPostgreSQL'] = (python_df['PostgreSQL user']/python_df['num_people']) * 100
python_df.head(10)
# Out:
#                                                     num_people  \
# United States of America                                 15288
# India                                                    10511
# Germany                                                   5625
# United Kingdom of Great Britain and Northern Ir...        4475
# Canada                                                    3012
# France                                                    2708
# Brazil                                                    2254
# Poland                                                    1805
# Netherlands                                               1772
# Italy                                                     1666
#
#                                                     PostgreSQL user  \
# United States of America                                       6524
# India                                                          3336
# ...

# %%
x=country_grp['MiscTechHaveWorkedWith'].apply(lambda x: x.str.contains('Pandas').sum())
python_df = pd.concat([country_respondents, x], axis='columns', sort=False)
python_df.rename(columns={'MiscTechHaveWorkedWith': 'Pandas user','Country':'num_people'}, inplace=True)
python_df.head(10)
# Out:
#                                                     num_people  Pandas user
# United States of America                                 15288         4513
# India                                                    10511         3855
# Germany                                                   5625         1530
# United Kingdom of Great Britain and Northern Ir...        4475         1270
# Canada                                                    3012          871
# France                                                    2708          819
# Brazil                                                    2254          635
# Poland                                                    1805          496
# Netherlands                                               1772          511
# Italy                                                     1666          447

# %%
df['Currency'].value_counts(normalize=True)[:20].plot(kind='bar');
# Out:
# C:\Users\Ali\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Ali\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.countplot(data=df,x='CompFreq',color='b')
sns.set(rc={'figure.figsize': [10,5]}, font_scale=2)
plt.title('number of people who get paid ');

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'EdLevel', 'Age1stCode',
#        'LearnCode', 'YearsCode', 'YearsCodePro', 'DevType', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'DatabaseHaveWorkedWith', 'WebframeHaveWorkedWith',
#        'MiscTechHaveWorkedWith', 'NEWCollabToolsHaveWorkedWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'NEWOtherComms',
#        'Age', 'Gender'],
#       dtype='object')

# %%
x=lang['LanguageHaveWorkedWith']=='Python'
lang.loc[x,['CompTotal','Country','Currency']]
# Out:
#             CompTotal                                            Country  \
# ResponseId
# 1              4800.0                                           Slovakia
# 2             67000.0                                        Netherlands
# 3             67000.0                                 Russian Federation
# 4             67000.0                                            Austria
# 5             67000.0  United Kingdom of Great Britain and Northern I...
# ...               ...                                                ...
# 83435        160500.0                           United States of America
# 83436        200000.0                                              Benin
# 83437          1800.0                           United States of America
# 83438         90000.0                                             Canada
# 83439          7700.0                                             Brazil
#
#                                Currency
# ResponseId
# ...

# %%
df['Gender'].value_counts().plot(kind='bar');
